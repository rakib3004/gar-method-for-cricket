# %% [markdown]
# <a href="https://colab.research.google.com/github/rakib3004/gar-method-for-cricket/blob/main/SPL3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fetch Sura Doc when hits into
# This url : [Surah Fatiha](https://www.hadithbd.com/quran/byword/detail/?sura=1)

# %%
# !pip install os
# Out:
# ERROR: Could not find a version that satisfies the requirement os (from versions: none)
# ERROR: No matching distribution found for os

# %%
import os
import requests
import re

# Replace this URL with the actual URL you want to fetch files from
url = "https://www.hadithbd.com/quran/byword/detail/?sura=1"

response = requests.get(url)

if response.status_code == 200:
    # Create a directory to save the files if it doesn't exist
    if not os.path.exists("src/downloaded_files"):
        os.makedirs("src/downloaded_files")

    # Extract filenames from the content-disposition header
    content_disposition = response.headers.get("content-disposition")
    filenames = re.findall(r'filename="(.*?)"', content_disposition) if content_disposition else []

    for filename in filenames:
          file_url = url + filename
          file_response = requests.get(file_url)

          if file_response.status_code == 200:
              # Save the file to the specified directory
              file_path = os.path.join("downloaded_files", filename)
              with open(file_path, "wb") as file:
                  file.write(file_response.content)

              print(f"Downloaded and saved: {filename}")
          else:
              print(f"Failed to download: {filename}")
else:
    print("Failed to fetch files")

print("All doc files downloaded and saved.")
# Out:
# All doc files downloaded and saved.

# %%
# !pip install re
# Out:
# ERROR: Could not find a version that satisfies the requirement re (from versions: none)
# ERROR: No matching distribution found for re

# %% [markdown]
# # Parse HTML file to separate ayat no, bangla and english word

# %%
import re
import pandas as pd

# Your HTML code snippet
html_code = """
      <div class="card-text">

            <div dir="rtl" class="container">
              <div  class="row">




                  <p class="text-info text-right">(1)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">حمٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">হা-মীম</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Ha Meem</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(2)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">تَنزِيلٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অবতরণ করা (হয়েছে এটা)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">A revelation</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">مِّنَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">(আল্লাহর) পক্ষ হ&#x27;তে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">from</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلرَّحْمَٰنِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">(যিনি) অশেষ দয়াময়</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the Most Gracious</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلرَّحِيمِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পরম দয়ালু</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the Most Merciful</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(3)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">كِتَٰبٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এই কিতাব (এমন যে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">A Book</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فُصِّلَتْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">বিশদভাবে বিবৃত</p>
                    <p dir="ltr"  class="font-kalpurush-reading">are detailed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ءَايَٰتُهُۥ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার আয়াতসমূহ</p>
                    <p dir="ltr"  class="font-kalpurush-reading">its Verses</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">قُرْءَانًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">কুরআন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">a Quran</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">عَرَبِيًّا</p>

                    <p dir="ltr" class="font-kalpurush-reading">আরবী (ভাষার)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(in) Arabic</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لِّقَوْمٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">(এমন) সম্প্রদায়ের জন্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">for a people</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يَعْلَمُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">(যারা) জ্ঞান রাখে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">who know</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(4)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بَشِيرًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">(এই কিতাব) সুসংবাদদাতা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">A giver of glad tidings</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَنَذِيرًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">ও সতর্ককারী</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and a warner;</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَأَعْرَضَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">কিন্তু বিমুখ হয়েছে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">but turn away</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَكْثَرُهُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাদের অনেকেই</p>
                    <p dir="ltr"  class="font-kalpurush-reading">most of them</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَهُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">সুতরাং তারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">so they</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">না</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(do) not</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يَسْمَعُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">শুনে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">hear</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(5)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَقَالُوا۟</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং তারা বলে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">And they say</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">قُلُوبُنَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">&quot;আমাদের অন্তরগুলো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">&quot;Our hearts</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِىٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্যে (আছে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(are) in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَكِنَّةٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পর্দাসমূহের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">coverings</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">مِّمَّا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তা থেকে যা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">from what</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">تَدْعُونَآ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আমাদেরকে তোমরা ডাকছো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">you call us</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَيْهِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার দিকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">to it</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَفِىٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ءَاذَانِنَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">আমাদের কানসমূহের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">our ears</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَقْرٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">বধিরতা (রয়েছে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is) deafness</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَمِنۢ</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্য হতে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and between us</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بَيْنِنَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং আমাদের মাঝে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and between us</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَبَيْنِكَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ও তোমার মাঝে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and between you</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">حِجَابٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পর্দা (রয়েছে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is) a screen</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَٱعْمَلْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তুমি তাই কাজ করো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">So work</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِنَّنَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">নিশ্চয়ই আমরা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">indeed, we</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">عَٰمِلُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">কাজ করে যাচ্ছি&quot;</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(are) working&quot;</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(6)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">قُلْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">(হে নাবী) বলো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Say</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِنَّمَآ</p>

                    <p dir="ltr" class="font-kalpurush-reading">&quot;মূলতঃ</p>
                    <p dir="ltr"  class="font-kalpurush-reading">&quot;Only</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَنَا۠</p>

                    <p dir="ltr" class="font-kalpurush-reading">আমি</p>
                    <p dir="ltr"  class="font-kalpurush-reading">I am</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بَشَرٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">একজন মানুষ</p>
                    <p dir="ltr"  class="font-kalpurush-reading">a man</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">مِّثْلُكُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তোমাদেরই মতো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">like you</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يُوحَىٰٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ওহী করা হয়</p>
                    <p dir="ltr"  class="font-kalpurush-reading">it is revealed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَىَّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আমার প্রতি</p>
                    <p dir="ltr"  class="font-kalpurush-reading">to me</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَنَّمَآ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এই যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">that</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَٰهُكُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তোমাদের ইলাহ</p>
                    <p dir="ltr"  class="font-kalpurush-reading">your god</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَٰهٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ইলাহ</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is) God</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَٰحِدٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">একই</p>
                    <p dir="ltr"  class="font-kalpurush-reading">One;</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَٱسْتَقِيمُوٓا۟</p>

                    <p dir="ltr" class="font-kalpurush-reading">সুতরাং তোমরা দৃঢ় হয়ে থাকো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">so take a Straight Path</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَيْهِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাঁর দিকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">to Him</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَٱسْتَغْفِرُوهُ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ও তোমরা তাঁর কাছে ক্ষমা চাও&quot;</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and ask His forgiveness&quot;</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَوَيْلٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং দুর্ভোগ (রয়েছে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">And woe</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لِّلْمُشْرِكِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">মুশরিকদের জন্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">to the polytheists</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(7)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلَّذِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">যারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Those who</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">না</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(do) not</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يُؤْتُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">দেয়</p>
                    <p dir="ltr"  class="font-kalpurush-reading">give</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلزَّكَوٰةَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">যাকাত</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the zakah</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَهُم</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং তারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and they</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بِٱلْءَاخِرَةِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পরকালকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in the Hereafter</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">هُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">they</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">كَٰفِرُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অস্বীকারকারী</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(are) disbelievers</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(8)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِنَّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">নিশ্চয়ই</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Indeed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلَّذِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">যারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">those who</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ءَامَنُوا۟</p>

                    <p dir="ltr" class="font-kalpurush-reading">ঈমান এনেছে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">believe</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَعَمِلُوا۟</p>

                    <p dir="ltr" class="font-kalpurush-reading">ও কাজ করেছে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and do</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلصَّٰلِحَٰتِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">নেক</p>
                    <p dir="ltr"  class="font-kalpurush-reading">righteous deeds</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَهُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাদের জন্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">for them</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَجْرٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পুরস্কার রয়েছে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is) a reward</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">غَيْرُ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ব্যতীত</p>
                    <p dir="ltr"  class="font-kalpurush-reading">never ending</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">مَمْنُونٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">শেষ হওয়া (অফুরন্ত)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">never ending</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(9)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">قُلْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">বলো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Say</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَئِنَّكُمْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">&quot;তোমরা নিশ্চিত কি</p>
                    <p dir="ltr"  class="font-kalpurush-reading">&quot;Do you indeed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَتَكْفُرُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অস্বীকার করছো অবশ্যই</p>
                    <p dir="ltr"  class="font-kalpurush-reading">[surely] disbelieve</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بِٱلَّذِى</p>

                    <p dir="ltr" class="font-kalpurush-reading">(তাকে) যিনি</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in the One Who</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">خَلَقَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">সৃষ্টি করেছেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">created</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلْأَرْضَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পৃথিবীকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the earth</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِى</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يَوْمَيْنِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">দু&#x27;দিনের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">two periods</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَتَجْعَلُونَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অথচ তোমরা দাঁড় করাচ্ছো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and you set up</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَهُۥٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাঁর জন্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">with Him</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَندَادًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">সমকক্ষ (অন্যদেরকে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">rivals?</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ذَٰلِكَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তিনিই</p>
                    <p dir="ltr"  class="font-kalpurush-reading">That</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">رَبُّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">রব</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is the) Lord</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلْعَٰلَمِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">বিশ্বজগতের&quot;</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(of) the worlds&quot;</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(10)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَجَعَلَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং তিনি স্হাপন করেছেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">And He placed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِيهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার মধ্যে (অর্থাৎ পৃথিবীতে)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">therein</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">رَوَٰسِىَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">পর্বতমালা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">firmly-set mountains</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">مِن</p>

                    <p dir="ltr" class="font-kalpurush-reading">থেকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">above it</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَوْقِهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার উপর</p>
                    <p dir="ltr"  class="font-kalpurush-reading">above it</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَبَٰرَكَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং কল্যাণ দিয়েছেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and He blessed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِيهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">therein</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَقَدَّرَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং নির্ধারণ করেছেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and determined</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِيهَآ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">therein</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَقْوَٰتَهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তার খাদ্য (অর্থাৎ খাদ্যসম্ভার)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">its sustenance</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِىٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَرْبَعَةِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">চার</p>
                    <p dir="ltr"  class="font-kalpurush-reading">four</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَيَّامٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">দিনের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">periods</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">سَوَآءً</p>

                    <p dir="ltr" class="font-kalpurush-reading">সমানভাবে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">equal</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لِّلسَّآئِلِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">প্রার্থীদের জন্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">for those who ask</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(11)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ثُمَّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এরপর</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Then</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱسْتَوَىٰٓ</p>

                    <p dir="ltr" class="font-kalpurush-reading">মনোযোগ দিলেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">He directed (Himself)</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">إِلَى</p>

                    <p dir="ltr" class="font-kalpurush-reading">দিকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">towards</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلسَّمَآءِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আকাশের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the heaven</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَهِىَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">তখন তা (ছিলো)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">while it (was)</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">دُخَانٌ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ধোঁয়া</p>
                    <p dir="ltr"  class="font-kalpurush-reading">smoke</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَقَالَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অতঃপর (আল্লাহ) বললেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and He said</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">لَهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">to it</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَلِلْأَرْضِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ও পৃথিবীকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and to the earth</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱئْتِيَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">&quot;উভয়ে আসো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">&quot;Come both of you</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">طَوْعًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">ইচ্ছায়</p>
                    <p dir="ltr"  class="font-kalpurush-reading">willingly</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَوْ</p>

                    <p dir="ltr" class="font-kalpurush-reading">বা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">or</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">كَرْهًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">অনিচ্ছায়&quot;</p>
                    <p dir="ltr"  class="font-kalpurush-reading">unwillingly&quot;</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">قَالَتَآ</p>

                    <p dir="ltr" class="font-kalpurush-reading">উভয়ে বললো</p>
                    <p dir="ltr"  class="font-kalpurush-reading">They both said</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَتَيْنَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">&quot;আমরা আসলাম</p>
                    <p dir="ltr"  class="font-kalpurush-reading">&quot;We come</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">طَآئِعِينَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">স্বেচ্ছায়&quot;</p>
                    <p dir="ltr"  class="font-kalpurush-reading">willingly&quot;</p>
                    <hr>

                  </div>


                  <p class="text-info text-right">(12)</p>


                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فَقَضَىٰهُنَّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">অতঃপর তাদেরকে পরিণত করলেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">Then He completed them</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">سَبْعَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">সাত</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(as) seven</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">سَمَٰوَاتٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আকাশে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">heavens</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِى</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">يَوْمَيْنِ</p>

                    <p dir="ltr" class="font-kalpurush-reading">দু&#x27;দিনের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">two periods</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَأَوْحَىٰ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং ওহী করলেন</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and He revealed</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">فِى</p>

                    <p dir="ltr" class="font-kalpurush-reading">মধ্যে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">in</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">كُلِّ</p>

                    <p dir="ltr" class="font-kalpurush-reading">প্রত্যেক</p>
                    <p dir="ltr"  class="font-kalpurush-reading">each</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">سَمَآءٍ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আকাশের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">heaven</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">أَمْرَهَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">তাঁর বিধিবিধান</p>
                    <p dir="ltr"  class="font-kalpurush-reading">its affair</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَزَيَّنَّا</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং আমরা সাজালাম</p>
                    <p dir="ltr"  class="font-kalpurush-reading">And We adorned</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلسَّمَآءَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">আকাশকে</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the heaven</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ٱلدُّنْيَا</p>

                    <p dir="ltr" class="font-kalpurush-reading">নীচের</p>
                    <p dir="ltr"  class="font-kalpurush-reading">the nearest</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">بِمَصَٰبِيحَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">প্রদীপমালা দ্বারা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">with lamps</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">وَحِفْظًا</p>

                    <p dir="ltr" class="font-kalpurush-reading">এবং সংরক্ষণ (করলাম)</p>
                    <p dir="ltr"  class="font-kalpurush-reading">and (to) guard</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">ذَٰلِكَ</p>

                    <p dir="ltr" class="font-kalpurush-reading">এটা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">That</p>
                    <hr>

                  </div>

                  <div class="col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all">
                    <p dir="rtl">تَقْدِيرُ</p>

                    <p dir="ltr" class="font-kalpurush-reading">ব্যবস্থাপনা</p>
                    <p dir="ltr"  class="font-kalpurush-reading">(is the) Decree</p>
                    <hr>

                  </div>

              """

# Extract ayat numbers, Arabic words, and Bengali words
arabic_pattern = r'dir="rtl">([^<]+)</p>'
bengali_pattern = r'dir="ltr" class="font-kalpurush-reading">([^<]+)</p>'

arabic_words = re.findall(arabic_pattern, html_code)
bengali_words = re.findall(bengali_pattern, html_code)

# Create a pandas DataFrame
data = { 'Arabic Word': arabic_words, 'Bengali Word': bengali_words}
df = pd.DataFrame(data)

pd.set_option('display.max_rows', None)

# Print the DataFrame
print(df)
# Out:
#           Arabic Word                       Bengali Word
# 0                 حمٓ                             হা-মীম
# 1            تَنزِيلٌ             অবতরণ করা (হয়েছে এটা)
# 2               مِّنَ           (আল্লাহর) পক্ষ হ&#x27;তে
# 3        ٱلرَّحْمَٰنِ                (যিনি) অশেষ দয়াময়
# 4          ٱلرَّحِيمِ                          পরম দয়ালু
# 5             كِتَٰبٌ                  এই কিতাব (এমন যে)
# 6           فُصِّلَتْ                     বিশদভাবে বিবৃত
# 7         ءَايَٰتُهُۥ                      তার আয়াতসমূহ
# 8          قُرْءَانًا                              কুরআন
# 9          عَرَبِيًّا                       আরবী (ভাষার)
# 10          لِّقَوْمٍ            (এমন) সম্প্রদায়ের জন্যে
# 11        يَعْلَمُونَ                  (যারা) জ্ঞান রাখে
# 12           بَشِيرًا             (এই কিতাব) সুসংবাদদাতা
# 13         وَنَذِيرًا                        ও সতর্ককারী
# 14         فَأَعْرَضَ                কিন্তু বিমুখ হয়েছে
# ...

# %% [markdown]
# # **Save Web Page HTML**

# %%
import requests
import os

# Replace with the URL you want to fetch
url = 'https://www.hadithbd.com/quran/byword/detail/?sura=1'
response = requests.get(url)

html_content = response.content
file_name = '/content/drive/MyDrive/SPL3/Colab/web_page.html'

with open(file_name, 'wb') as f:
    f.write(html_content)

print(f'Web page content saved as {file_name}')
# Out:
# Web page content saved as /content/drive/MyDrive/SPL3/Colab/web_page.html

# %% [markdown]
# # **Fetch All Sura**

# %%
import requests
import os

# Base URL
base_url = 'https://www.hadithbd.com/quran/byword/detail/?sura='

# Loop through sura numbers (1 to 114)
for sura_number in range(1, 115):
    url = base_url + str(sura_number)
    response = requests.get(url)

    html_content = response.content
    file_name = f'/content/drive/MyDrive/SPL3/Colab/Sura{sura_number}.html'

    with open(file_name, 'wb') as f:
        f.write(html_content)

    print(f'Web page content for Sura {sura_number} saved as {file_name}')

# %% [markdown]
# # **Make Sura Database**

# %%
# !pip install bs4

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Function to extract verse information from a surah file
def extract_verse_info(surah_file):
    with open(surah_file, 'r', encoding='utf-8') as file:
        content = file.read()

    soup = BeautifulSoup(content, 'html.parser')


    verses = []
    for verse_tag in soup.find_all('p', class_='text-info text-right'):
        verse_number = (verse_tag.text)
        arabic_word = verse_tag.find_next('p', dir='rtl').text
        english_word = verse_tag.find_next('p', dir='ltr', class_='font-kalpurush-reading').text
        bangla_word = verse_tag.find_next('p', dir='ltr', class_='font-kalpurush-reading').text

        verses.append({
            'Verse Number': verse_number,
            'Arabic Word': arabic_word,
            'Bangla Word': bangla_word
        })

    return verses

# Path to the directory containing surah files
surah_dir = '/content/drive/MyDrive/SPL3/Quranic/Colab/'

# List to store verse information from all surahs
all_verses = []

# Iterate through surah files and extract verse information
for filename in os.listdir(surah_dir):
    if filename.endswith('.html'):
        surah_file = os.path.join(surah_dir, filename)
        verses = extract_verse_info(surah_file)
        all_verses.extend(verses)

# Create a pandas DataFrame
quran_df = pd.DataFrame(all_verses)

# Display the DataFrame
# pd.set_option('display.max_rows', None)
# print(quran_df)

output_csv_path = os.path.join(surah_dir, 'dataset001.csv')
quran_df.to_csv(output_csv_path, index=False)

print(f"Quran data saved to: {output_csv_path}")
# Out:
# Quran data saved to: /content/drive/MyDrive/SPL3/Quranic/Colab/dataset001.csv

# %%
# Out:
#  Quranic/  'William Merry'/

# %% [markdown]
# # **Quranic Vocabulary Learning Model Tensorflow**

# %%
# !pip install tensorflow numpy pandas

# %%
import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# Load your dataset
# Replace 'dataset.csv' with your actual dataset file
df = pd.read_csv('/content/drive/MyDrive/SPL3/Colab/quran_data.csv')

# Preprocess data
tokenizer = Tokenizer()
tokenizer.fit_on_texts(df['Arabic Word'])
vocab_size = len(tokenizer.word_index) + 1

sequences = tokenizer.texts_to_sequences(df['Arabic Word'])
max_sequence_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

# Create training data
X_train = padded_sequences
y_train = pd.get_dummies(df['Bangla Word']).values

# %%
model = Sequential()
model.add(Embedding(vocab_size, 50, input_length=max_sequence_length))
model.add(LSTM(100))
model.add(Dense(y_train.shape[1], activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.fit(X_train, y_train, epochs=50, batch_size=64, validation_split=0.2)

# %%
while True:
    # Generate a verse based on user's previous performance
    # You can customize this part based on your dataset and model
    user_input = input("Enter a verse or type 'quit' to exit: ")
    if user_input.lower() == 'quit':
        break

    arabic_words = user_input.split()
    arabic_word_sequences = tokenizer.texts_to_sequences(arabic_words)
    padded_word_sequences = pad_sequences(arabic_word_sequences, maxlen=max_sequence_length, padding='post')

    # Predict Bengali meanings for the provided Arabic words
    predicted_meanings = model.predict(padded_word_sequences)
    predicted_meaning_indices = np.argmax(predicted_meanings, axis=1)

    # Print predicted Bengali meanings
    for i, index in enumerate(predicted_meaning_indices):
        predicted_meaning = df[df['Bangla Word'].str.match(tokenizer.index_word[index])]
        print(f"Arabic Word: {arabic_words[i]} - Predicted Meaning: {predicted_meaning.iloc[0]['Bangla Word']}")

    # Ask the user for their performance and update the model if needed
    user_feedback = input("Did the predictions match? (yes/no): ")
    if user_feedback.lower() == 'no':
        for i, index in enumerate(predicted_meaning_indices):
            correct_meaning = df[df['Arabic Word'] == arabic_words[i]]['Bangla Word']
            correct_meaning_index = tokenizer.word_index[correct_meaning.iloc[0]]
            y_train[0][correct_meaning_index] = 1  # Mark the correct meaning for update
        model.fit(padded_word_sequences, y_train, epochs=10, batch_size=1)

# %% [markdown]
# # **Fetch All Surah with all pages**

# %%
import requests
import os

# Base URL


# Loop through sura number 2
for sura_number in range(1,115):
    page=0
    while page <= 15:
      print(page)
      url = f'https://www.hadithbd.com/quran/byword/detail/?pageNum_suraGroup={page}&sura={sura_number}'
      response = requests.get(url)
      html_content = response.content
      if(len(html_content)<35000):
        this_page_length = len(html_content)
        next_page_url = f'https://www.hadithbd.com/quran/byword/detail/?pageNum_suraGroup={page+1}&sura={sura_number}'
        next_page_response = requests.get(next_page_url)
        next_page_html_content = next_page_response.content
        next_page_length = len(next_page_html_content)
        print(this_page_length,this_page_length)
        if(this_page_length==next_page_length):
          break;

      file_name = f'/content/drive/MyDrive/SPL3/Quranic/Colab/Test/Surah{sura_number}.{page+1}.html'

      with open(file_name, 'wb') as f:
          f.write(html_content)

      print(f'Surah{sura_number}.{page+1} Length = {len(html_content)}')
      page = page + 1

# %%
ls -l | grep -c '^-'
# Out:
# 382

# %% [markdown]
# # **Create Full Quranic Bangla Database**

# %%
import os
import re
import pandas as pd
from bs4 import BeautifulSoup

# Function to extract verse information from a surah file
def extract_verse_info(surah_file, filename):
    with open(surah_file, 'r', encoding='utf-8') as file:
        content = file.read()

    soup = BeautifulSoup(content, 'html.parser')
    surah_number = ""
    for char in filename:
        if char.isdigit() or char == '-':
            surah_number += char
        elif surah_number and not char.isdigit():
            break
    print('Surah Number is', surah_number)

    verses = []
    for verse_tag in soup.find_all('p', class_='text-info text-right'):
      verse_number_with_error = (verse_tag.text)
      print('error',verse_number_with_error)
      verse_number = verse_number_with_error.replace("-", "")
      print('latest',verse_number_with_error)

      for word_tag in soup.find_all('div', class_='col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all'):
        #col-lg-2 col-md-3 col-sm-6 mb-4 text-right box user-select-all

        arabic_word = word_tag.find_next('p', dir='rtl').text
        english_word = word_tag.find_next('p', dir='ltr', class_='font-kalpurush-reading').text
        bangla_word = word_tag.find_next('p', dir='ltr', class_='font-kalpurush-reading').text



        verses.append({
            'Surah Number': surah_number,
            'Verse Number': verse_number,
            'Arabic Word': arabic_word,
            'Bangla Word': bangla_word
        })

    return verses

# Path to the directory containing surah files
surah_dir = '/content/drive/MyDrive/SPL3/Quranic/Colab/Test'

# List to store verse information from all surahs
all_verses = []

# Iterate through surah files and extract verse information
counter=0
for filename in os.listdir(surah_dir):
    if filename.endswith('.html'):
        if(counter>3):
          break
        print(filename)
        surah_file = os.path.join(surah_dir, filename)
        verses = extract_verse_info(surah_file,filename)
        all_verses.extend(verses)
        counter=counter+1
# Create a pandas DataFrame
quran_df = pd.DataFrame(all_verses)

# Display the DataFrame
# pd.set_option('display.max_rows', None)
# print(quran_df)

output_csv_path = os.path.join(surah_dir, 'database/quranic_bangla.csv')
quran_df.to_csv(output_csv_path, index=False)

print(f"Complete Database Successfully")
# Out:
# Surah100.2.html
# Surah Number is 100
# Surah100.3.html
# Surah Number is 100
# Surah100.5.html
# Surah Number is 100
# Surah100.4.html
# Surah Number is 100
# Complete Database Successfully
